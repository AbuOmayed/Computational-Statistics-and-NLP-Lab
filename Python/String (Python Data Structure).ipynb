# %% [markdown]
# <h1>Python Data Structure</h1>
# <ul>
#     <li>List</li>
#     <li>Tuple</li>
#     <li>Set</li>
#     <li>String</li>
#     <li>Dictionary</li>
# </ul>

# %% [markdown]
# ### String
# - A String is a sequense of Characters.
# - A string contained within two/single quotes.

# %%
print("Micheal Jackson")
# Out:
# Micheal Jackson

# %%
name = "Micheal Jackson"

# %%
print(name)
# Out:
# Micheal Jackson

# %%
type(name)
# Out:
# str

# %% [markdown]
# - A String can be spaces or digit.

# %%
B = "1 2 3 4"

# %%
type(B)
# Out:
# str

# %%
print(B)
# Out:
# 1 2 3 4

# %% [markdown]
# - A string can also be special character.

# %%
C = "@#$%^&&**()"

# %%
type(C)
# Out:
# str

# %% [markdown]
# ### String Index

# %%
name = "Michale Jackson"

# %%
print(name)
# Out:
# Michale Jackson

# %%
name[4]
# Out:
# 'a'

# %% [markdown]
# - We can bind string.

# %%
name[0:4]
# Out:
# 'Mich'

# %% [markdown]
# - Print every second element.

# %%
name[::2]
# Out:
# 'McaeJcsn'

# %% [markdown]
# - Incorporate slicing

# %%
name[0:6:2]
# Out:
# 'Mca'

# %% [markdown]
# ### Modified String

# %% [markdown]
# - .upper() method returns the string in Upper case.

# %%
name.upper()
# Out:
# 'MICHALE JACKSON'

# %% [markdown]
# - .lower() method returns the string in lower case.

# %%
name.lower()
# Out:
# 'michale jackson'

# %% [markdown]
# ### Combined string

# %%
A = "Pyhton "
B = "Programming"

# %%
c = A + B

# %%
print(c)
# Out:
# Pyhton Programming

# %%
statement = name + "is the best singer"

# %%
statement
# Out:
# 'Michale Jacksonis the best singer'

# %% [markdown]
# ### Format String

# %%
income = 5000
statement = "My monthly income is " + str(income) + " taka"
statement
# Out:
# 'My monthly income is 5000 taka'

# %% [markdown]
# - Create an f string.

# %%
statement = f"My monthly income is {income} taka"
statement
# Out:
# 'My monthly income is 5000 taka'

# %% [markdown]
# - By using f string you can do mathematical operation

# %%
statement = f"My yearly income is {income*12} taka"
statement
# Out:
# 'My yearly income is 60000 taka'

# %% [markdown]
# ### Escape Characters
#
# - \ meant to proceed escape sequence

# %%
name = "Mical \ Jackson"

# %%
name
# Out:
# 'Mical \\ Jackson'

# %% [markdown]
# - \\" Double code

# %%
print("My name is "Mical".")
# Out:
#   Cell In[46], line 1
#     print("My name is "Mical".")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("My name is \"Mical\".")
# Out:
# My name is "Mical".

# %% [markdown]
# - \\n New line

# %%
print("My name is Mical.\n And i am a singer.")
# Out:
# My name is Mical.
#  And i am a singer.

# %% [markdown]
# ### List Method
#
# - <b>capitalize()</b>  Converts the first character to upper case
# - <b>count()</b>   Returns the number of times a specified value occurs in a string
# - <b>find()</b>	Searches the string for a specified value and returns the position of where it was found
# - <b>format()</b>	Formats specified values in a string
# - <b>islower()</b>	Returns True if all characters in the string are lower case
# - <b>index()</b>	Returns the index of the first element with the specified value
# - <b>replace()</b> Returns a string where a specified value is replaced with a specified value

# %% [markdown]
# - capitalize() Converts the first character to upper case

# %%
name = "kazi nazrul Islam"

# %%
name.capitalize()
# Out:
# 'Kazi nazrul islam'

# %% [markdown]
# - count() Returns the number of times a specified value occurs in a string

# %%
name.count("i")
# Out:
# 1

# %%
name
# Out:
# 'kazi nazrul Islam'

# %% [markdown]
# - find() Searches the string for a specified value and returns the position of where it was found

# %%
name.find("I")
# Out:
# 12

# %% [markdown]
# - format() Formats specified values in a string

# %%
txt = "My monthly income is {} taka"
print(txt.format(12.3453))
# Out:
# My monthly income is 12.3453 taka

# %%
print("My montly income is {} taka".format(123.12))
# Out:
# My montly income is 123.12 taka

# %%
print("My name is {fname}, I'm {age}".format(fname = "John", age = 36))
# Out:
# My name is John, I'm 36

# %% [markdown]
# - islower() Returns True if all characters in the string are lower case

# %%
name.islower()
# Out:
# False

# %% [markdown]
# - index() Returns the index of the first element with the specified value

# %%
txt = "Hello, welcome to my world."

x = txt.index("welcome")

print(x)
# Out:
# 7

# %% [markdown]
# - replace() Returns a string where a specified value is replaced with a specified value

# %%
txt = "I like bananas"

x = txt.replace("bananas", "apples")

print(x)
# Out:
# I like apples

# %%
txt = "one one was a race horse, two two was one too."

x = txt.replace("one", "three", 2)

print(x)
# Out:
# three three was a race horse, two two was one too.
