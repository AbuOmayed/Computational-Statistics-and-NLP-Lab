# %% [markdown]
# <h1>Python Data Structure</h1>
# <ul>
#     <li>List</li>
#     <li>Tuple</li>
#     <li>Set</li>
#     <li>String</li>
#     <li>Dictionary</li>
# </ul>

# %% [markdown]
# ### List
# - A list is represent with square bracket [].

# %%
A = [2,4,6,8,10]

# %%
type(A)
# Out:
# list

# %% [markdown]
# - A list can conation any Python type

# %%
B = ["Omayed", 2, 2.5, True]

# %%
type(B)
# Out:
# list

# %%
print(B)
# Out:
# ['Omayed', 2, 2.5, True]

# %% [markdown]
# - A list can contain list of list

# %%
C = [["Abu", "Omayed"], [1,3,4]]

# %%
type(C)
# Out:
# list

# %%
matrix = [[1,2,3], [3,5,6]]

# %%
matrix
# Out:
# [[1, 2, 3], [3, 5, 6]]

# %% [markdown]
# - We can combined the list by adding.

# %%
D = A + B

# %%
print(D)
# Out:
# [2, 4, 6, 8, 10, 'Omayed', 2, 2.5, True]

# %%
type(D)
# Out:
# list

# %% [markdown]
# - We add more element by using extend() function.

# %%
A.append([4])

# %%
A
# Out:
# [2, 4, 6, 8, 10, [False], [5], [4]]

# %%
name = [2,4,5]

# %%
name
# Out:
# [2, 4, 5]

# %%
name.append(6)

# %%
name
# Out:
# [2, 4, 5, 6]

# %% [markdown]
# - We can Change List element.

# %%
name = ["my", "Omayed"]

# %%
name
# Out:
# ['my', 'Omayed']

# %%
name[0] = "Abu"

# %%
name
# Out:
# ['Abu', 'Omayed']

# %% [markdown]
# - We can delete an element from list.

# %%
del(name[0])

# %%
name
# Out:
# ['Omayed']

# %% [markdown]
# - Convert string to list using split().

# %%
lab1 = "Computational Statistics and NLP Lab"

# %%
type(lab1)
# Out:
# str

# %%
lab = lab1.split()

# %%
lab
# Out:
# ['Computational', 'Statistics', 'and', 'NLP', 'Lab']

# %%
type(lab)
# Out:
# list

# %%
"Computational,statistics".split()
# Out:
# ['Computational,statistics']

# %%
"Computational,statistics".split(",")
# Out:
# ['Computational', 'statistics']

# %%
"Computational,statistics and NLP Lab".split(",")
# Out:
# ['Computational', 'statistics and NLP Lab']

# %%
"Computational,statistics and NLP Lab".split([",",""]) # wrong
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 "Computational,statistics and NLP Lab".split([",",""])
#
# TypeError: must be str or None, not list

# %% [markdown]
# ## List Index

# %%
word = ["a", "b", "c", ["d", "e"], "f"]

# %% [markdown]
# - Print second element from the list.

# %%
word[1]
# Out:
# 'b'

# %%
word[-4]
# Out:
# 'b'

# %% [markdown]
# - Print fourth element from the list.

# %%
word[3]
# Out:
# ['d', 'e']

# %%
word[3][0]
# Out:
# 'd'

# %% [markdown]
# - Print 1st to 3rd value from the list.
# - syntax: my_list[start:end]
# - end value not included

# %%
word[0:3]
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# - We can add two string or sum two values.

# %%
number = [4,5,6,7]

# %%
number[0] + number[2]
# Out:
# 10

# %%
word[0] + word[1]
# Out:
# 'ab'

# %% [markdown]
# - Copy list
# - If we change one element from any of list than the both list are changes.

# %%
y = number

# %%
y
# Out:
# [4, 5, 6, 7]

# %%
number.append(8)

# %%
number
# Out:
# [4, 5, 6, 7, 8]

# %%
y
# Out:
# [4, 5, 6, 7, 8]

# %% [markdown]
# - Colon list
# - Every list act as indivual list.

# %%
Z = number[:]  #or, Z = list(number)

# %%
Z
# Out:
# [4, 5, 6, 7, 8]

# %%
number.append(9)

# %%
number
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
Z
# Out:
# [4, 5, 6, 7, 8]
